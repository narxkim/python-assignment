# %%
from PIL import Image
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# %%
img = Image.open("cat1.jpg")
plt.imshow(img)
plt.show()

# %%
model = YOLO("yolo11n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 31.5MB/s 0.2s.1s<0.2s

# %%
results = model(img)
# Out:
# 0: 512x640 1 cat, 108.5ms
# Speed: 8.0ms preprocess, 108.5ms inference, 7.8ms postprocess per image at shape (1, 3, 512, 640)

# %%
for result in results:  # 탐지된 객체의 바운딩 박스가 그려진 이미지 가져오기
    annotated_frame = result.plot()  # 결과 화면에 출력

    cv2.imshow("YOLO Detection Result", annotated_frame)
    cv2.waitKey(0)

cv2.destroyAllWindows()
